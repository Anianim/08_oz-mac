# %% [markdown]
# 두 숫자를 더하는 람다 함수를 작성하고, 이를 변수에 할당한 후 사용하세요.

# %%
# lambda 매개변수 : 리턴값 으로 정의 할 수 있다. 람다는 익명함수로 간단한 함수 지정에 사용됨.

sum = lambda a,b : a+b # a , b 두 매개변수를 받아서 a+b 한다음 리턴한다 .

print(sum(1, 2)) # 파라미터로 1 과 2를 전달함.
# Out:
# 3
