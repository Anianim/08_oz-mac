# %% [markdown]
# 여러 숫자를 입력받아 그 합계를 반환하는 함수 sum_numbers를 작성하세요. 이 때, 가변 매개변수를 사용하세요.

# %%
# 함수 1개 와 여러숫자 = 가변 매개변수 의 합계
def sum_numbers(*number): # 함수 정의 () *변수명 사용할경우 가변매개변수로 지정한다 가변매개변수는 여러 값을 파라미터로 받을수 있음.
                          # 일반 매개변수가 있을 경우 뒤에 사용해야함
    total = sum(number)
    print(total)

sum_numbers(11, 12, 15, 16 , 18) # 함수 호출 및 매개변수 전달
# Out:
# 72
