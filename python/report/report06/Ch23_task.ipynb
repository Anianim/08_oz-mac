# %% [markdown]
# 사용자의 이름을 출력하는 함수 print_name을 작성하세요. 만약 이름이 주어지지 않았다면, 기본값으로 "익명"을 사용하세요.

# %%
# 사용자의 이름을 출력하는 함수 정의 하기 파라미터가 없다면 기본매개변수로 "익명" 을 사용

def print_name(name="익명"): # 기본매개변수로 name="익명" 지정 후 함수정의
    print(name) # 파라미터 출력 만약 파라미터가 없다면 "익명"이 출력됨.

print_name()
# Out:
# 익명
