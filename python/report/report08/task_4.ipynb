# %% [markdown]
# [문제]
#
# 'Employee' 클래스를 선언하세요.
#
# 이 클래스는 월급인상률을 의미하는 클래스 변수로 'raise_amount'를 갖고 있으며, 기본값은 1.04입니다. 다음 급여는 기본 급여에 월급인상률을 곱한 값으로 결정합니다.
#
# 또한, 각 직원의 이름(name)과 급여(salary)를 속성으로 가지며, 'apply_raise' 메소드를 통해 급여에 'raise_amount'를 적용할 수 있어야 합니다.
#
# 'Employee' 클래스의 객체 두 개를 생성하고, 한 객체에만 'raise_amount'를 변경한 후, 두 객체의 급여를 증가시켜보세요.<br>
# 그리고 각 객체의 새로운 급여를 출력하세요.

# %%
class Employee:
    raise_amount = 1.04
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def apply_raise(self):
        self.salary = self.salary * self.raise_amount

    def __str__(self):
        return f"이름: {self.name}, 급여: {self.salary:.0f}" # .0f 소수점 자리 제거
employee0 = Employee("강씨",1000000)
employee1 = Employee("고씨",1200000)

employee0.apply_raise()

print(employee0)
print(employee1)
# Out:
# 이름: 강씨, 급여: 1040000
# 이름: 고씨, 급여: 1200000
