# %% [markdown]
# ## 입력과 출력
#
# * 입력 : input()
# * 출력 : print()
#
# ##### 함수와 메서드
# >함수 : 어디에 속해있지 않고 단독 모듈이라 함수를 그냥 호출하여 사용이 가능합니다. ex) print() , input()
# https://docs.python.org/ko/3/library/functions.html
#
# >메서드 : 함수의 클래스 안에 속해 있고 클래스의 멤버 변수들을 이용해서 구현된것
# ex) "까먹으신건가요?" .count("까") / "까먹으신건가요?" .index("까")

# %%
"까먹으신건가요?" .count("까") # "까" 의 개수가 몇개인지 카운트
# Out:
# 1

# %%
"까먹으신건가요?" .index("까") # 까의 인덱스가 어디인지 나타내줌
# Out:
# 0

# %%
숫자, 문자 = 5, "5"
print(숫자 , 문자)
# Out:
# 5 5

# %%
인사 = input("(잘생긴남자)아 안녕")
print(인사+ " 눈부시게")
# Out:
# (잘생긴남자)아 안녕뭘 봐
# 뭘 봐 눈부시게

# %%
# int() , float(), str() , bool()
정수 = input()
정수 = int(정수)
print(정수, type(정수))

실수 = input()
실수 = float(실수)
print(실수, type(실수))
# Out:
# 5
# 5 <class 'int'>
# 5
# 5.0 <class 'float'>

# %%
정수 = int(input())
print(정수, type(정수))

실수 = float(input())
print(실수, type(실수))
# Out:
# 7
# 7 <class 'int'>
# 7
# 7.0 <class 'float'>

# %% [markdown]
# 그 외 입력값의 형변환이 가능한 종류
# * tuple()
# * list()
# * dict()
# * set()

# %%
#넌센스, 정답 = intput() #input은 한개의 문자열만 받을수 있다.

넌센스, 정답 = input().split(",") # split() 문자열을 잘라준다. 담는 변수의 개수 이상으로 자를 경우 에러 발생  too many values to unpack (expected 2)
                                 #  split("") 특정 문자열 지정시 문자열을 기준(default : 스페이스(공백)으로 잘라서 준다.
print(f'넌센스 퀴즈 : {넌센스}')
print(f'정답 : {정답}')
# Out:
# 스페인에서 에스파를 만나면 ? , 에스파냐
# 넌센스 퀴즈 : 스페인에서 에스파를 만나면 ?
# 정답 :  에스파냐

# %%
#시퀀스 자료형에 다 지원되는 메소드
번호1, 번호2, 번호3, 번호4 = input().split(",")

번호1 = int(번호1)
번호2 = int(번호2)
번호3 = int(번호3)
번호4 = int(번호4)

print(type(번호1), 번호2, 번호3, 번호4)
# Out:
# 1212, 2313214, 123 , 213
# <class 'int'> 2313214 123 213

# %%
#map()
번호1, 번호2, 번호3 , 번호4 = map(int, input().split(","))
print(type(번호1), 번호2, 번호3, 번호4)

# %%
#레거시 : 누군가 남겨두고간 코드
#리팩토링 : 결과의 변경 없이 코드의 구조를 재조정하는 것입니다.

# %%
#print() 함수에 기능을 이용해보겠습니다.

# print("초코칩", "민트", "샷추가", "휘핑크림")
# print("초코칩", "민트", "샷추가", "휘핑크림", sep="/")
# print("초코칩", "민트", "샷추가", "휘핑크림", sep=":")
# print("초코칩", "민트", "샷추가", "휘핑크림", sep="\n")

#, sep="" 각 값의 사이에 넣음.


print("초코칩", "민트", "샷추가", "휘핑크림", end='')
print("초코칩", "민트", "샷추가", "휘핑크림", end='아')
print("초코칩", "민트", "샷추가", "휘핑크림", end='\n')

#, end="" 끝에 추가 됨.
# Out:
# 초코칩 민트 샷추가 휘핑크림초코칩 민트 샷추가 휘핑크림아초코칩 민트 샷추가 휘핑크림
